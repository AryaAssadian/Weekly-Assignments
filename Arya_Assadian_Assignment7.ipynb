# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Heating Load (Non-Modified)

# %%
slices = [2850.9,4388.8,2472,2816.4]
Type_of_loss= ["Opaque","Fenestration","Infiltration","Distribution losses"]
cols = ["red","blue","yellow","green"]
plt.pie(slices,labels=Type_of_loss, colors=cols,startangle=90,shadow=True,explode=(0,0,0,0),autopct="%1.1f%%")
plt.title("Heating Load")
# Out:
# Text(0.5, 1.0, 'Heating Load')

# %% [markdown]
# Cooling Load (Non-Modified)

# %%
slices = [1330.9,3709.7,576,432.9,4295.2]
Type_of_loss = ["Opaque","Fenestration","Internal gain","Infiltration","Distribution losses"]
cols = ["purple","green","blue","yellow","red"]
plt.pie(slices,labels=Type_of_loss, colors=cols,startangle=90,shadow=True,explode=(0,0,0,0,0),autopct="%1.1f%%")
plt.title("Cooling Load")
# Out:
# Text(0.5, 1.0, 'Cooling Load')

# %% [markdown]
# Heating Load (Modified)

# %%
slices = [2850.9-473,4388.85,2472,2816.4]
Type_of_loss = ["Opaque","Fenestration","Infiltration","Distribution losses",]
cols = ["red","blue","yellow","green"]
plt.pie(slices,labels=Type_of_loss, colors=cols,startangle=90,shadow=True,explode=(0,0,0,0),autopct="%1.1f%%")
plt.title("Modified Heating Load")
# Out:
# Text(0.5, 1.0, 'Modified Heating')

# %% [markdown]
# Cooling Load (Modified)

# %%
slices = [1330.9-385.3,3709.7,576,432.9,4295.2]
activities = ["Opaque","Fenestration","Internal gain","Infiltration","Distribution losses"]
cols = ["purple","green","blue","yellow","red"]
plt.pie(slices,labels=activities, colors=cols,startangle=90,shadow=True,explode=(0,0,0,0,0),autopct="%1.1f%%")
plt.title("Modified Cooling Load")
# Out:
# Text(0.5, 1.0, 'Modified Cooling Load')
